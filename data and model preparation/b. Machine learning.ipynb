# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
import skimage
import skimage.color
import skimage.io
import skimage.feature
import skimage.transform

# %%
#Load the data
data = pickle.load(open('pickle files/data_animals_head_20.pickle','rb'))

# %%
data['description']
# Out:
# 'There are 20 classes and 2057 images. All the images are 80 x 80 (rgb)'

# %%
#split the data into independent and dependent
X = data['data'] #indepemdent
y = data['target'] #dependent

# %%
print(X)
# Out:
# [[[[196 214 188]
#    [196 214 188]
#    [196 214 188]
#    ...
#    [ 81  76  80]
#    [ 81  76  80]
#    [ 69  64  68]]
#
#   [[196 214 188]
#    [196 214 188]
#    [196 215 187]
#    ...
#    [ 82  77  81]
#    [ 83  78  82]
#    [ 77  72  76]]
#
#   [[193 213 185]
#    [194 214 186]
#    [194 214 186]
#    ...
#    [ 82  77  81]
#    [ 81  76  80]
#    [ 78  73  77]]
#
#   ...
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 70  65  69]
#    [ 65  60  64]
#    [ 62  57  63]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 66  61  65]
#    [ 62  57  61]
#    [ 64  59  65]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 56  51  55]
#    [ 79  74  78]
#    [ 70  63  70]]]
#
#
#  [[[  4   2   3]
#    [  7   5   6]
#    [  6   5   3]
#    ...
#    [ 42  31  25]
#    [ 46  35  29]
#    [ 45  32  26]]
#
#   [[  7   5   6]
#    [  5   4   2]
#    [  2   1   0]
#    ...
#    [ 22  11   5]
#    [ 43  32  26]
#    [ 47  36  30]]
#
#   [[  6   5   3]
#    [  3   2   0]
#    [  2   1   0]
#    ...
#    [ 33  24  17]
#    [ 48  39  32]
#    [ 54  45  38]]
#
#   ...
#
#   [[ 24  29   6]
#    [ 24  30   4]
#    [ 25  31   5]
#    ...
#    [116 116  80]
#    [115 117  80]
#    [127 129  92]]
#
#   [[ 22  27   4]
#    [ 23  28   5]
#    [ 24  29   6]
#    ...
#    [112 112  76]
#    [115 117  80]
#    [128 130  93]]
#
#   [[ 22  27   5]
#    [ 22  27   4]
#    [ 22  27   4]
#    ...
#    [106 106  70]
#    [112 114  77]
#    [126 128  91]]]
#
#
#  [[[104 109 102]
#    [104 111 103]
#    [108 115 107]
#    ...
#    [130 126 127]
#    [122 117 121]
#    [123 118 122]]
#
#   [[113 118 111]
#    [ 97 104  96]
#    [103 110 102]
#    ...
#    [111 107 108]
#    [129 124 128]
#    [150 145 149]]
#
#   [[126 133 125]
#    [112 119 111]
#    [110 117 109]
#    ...
#    [139 135 136]
#    [162 157 161]
#    [163 158 162]]
#
#   ...
#
#   [[214 214 202]
#    [206 206 194]
#    [202 200 187]
#    ...
#    [164 162 150]
#    [173 173 163]
#    [187 187 179]]
#
#   [[219 219 207]
#    [210 210 198]
#    [205 203 190]
#    ...
#    [170 168 156]
#    [174 174 164]
#    [188 188 180]]
#
#   [[214 214 202]
#    [201 201 189]
#    [198 196 183]
#    ...
#    [172 170 158]
#    [179 179 169]
#    [184 184 176]]]
#
#
#  ...
#
#
#  [[[147 154 113]
#    [145 152 111]
#    [146 153 112]
#    ...
#    [102 109  58]
#    [118 121  74]
#    [128 131  86]]
#
#   [[148 155 114]
#    [146 153 112]
#    [145 152 111]
#    ...
#    [120 128  71]
#    [138 142  91]
#    [151 155 105]]
#
#   [[147 154 112]
#    [146 153 111]
#    [144 151 109]
#    ...
#    [136 142  80]
#    [143 151  91]
#    [150 158  99]]
#
#   ...
#
#   [[137 142  88]
#    [146 150  99]
#    [145 148 101]
#    ...
#    [143 138 100]
#    [148 143 103]
#    [158 150 111]]
#
#   [[133 138  82]
#    [128 133  79]
#    [129 133  83]
#    ...
#    [158 153 115]
#    [157 152 112]
#    [154 149 109]]
#
#   [[130 135  79]
#    [128 133  79]
#    [135 139  88]
#    ...
#    [160 155 115]
#    [157 152 112]
#    [150 145 105]]]
#
#
#  [[[246 250 249]
#    [247 251 250]
#    [252 254 253]
#    ...
#    [136 118 114]
#    [143 124 118]
#    [145 126 120]]
#
#   [[244 248 247]
#    [252 255 255]
#    [243 245 244]
#    ...
#    [139 124 117]
#    [135 120 113]
#    [156 141 134]]
#
#   [[238 242 241]
#    [248 252 251]
#    [246 248 247]
#    ...
#    [128 118 109]
#    [128 118 109]
#    [141 131 122]]
#
#   ...
#
#   [[236 233 224]
#    [230 226 217]
#    [228 224 215]
#    ...
#    [159 142 126]
#    [152 135 119]
#    [150 133 117]]
#
#   [[234 231 222]
#    [233 230 221]
#    [229 225 216]
#    ...
#    [185 169 154]
#    [165 149 134]
#    [169 153 138]]
#
#   [[242 239 232]
#    [236 233 224]
#    [229 225 216]
#    ...
#    [193 177 162]
#    [185 169 154]
#    [175 159 144]]]
#
#
#  [[[ 85  78  32]
#    [ 79  72  26]
#    [ 79  72  26]
#    ...
#    [ 80  73  27]
#    [ 76  69  23]
#    [ 74  67  21]]
#
#   [[ 82  78  31]
#    [ 79  72  26]
#    [ 78  71  25]
#    ...
#    [ 78  71  25]
#    [ 75  68  24]
#    [ 71  64  20]]
#
#   [[ 81  77  30]
#    [ 80  73  27]
#    [ 77  70  24]
#    ...
#    [ 78  71  27]
#    [ 76  69  25]
#    [ 71  64  20]]
#
#   ...
#
#   [[ 85  55  17]
#    [ 92  60  22]
#    [ 90  58  20]
#    ...
#    [103 101  53]
#    [ 99  97  49]
#    [ 96  94  46]]
#
#   [[ 87  57  19]
#    [ 82  50  11]
#    [ 88  56  17]
#    ...
#    [104 100  53]
#    [101  97  50]
#    [ 98  94  47]]
#
#   [[ 82  53  13]
#    [ 83  51  12]
#    [ 92  60  21]
#    ...
#    [101  94  48]
#    [100  93  47]
#    [ 98  91  45]]]]

# %%
print(y)
# Out:
# ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', ' ...

# %%
#split the data into train and test
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %%
x_train.shape,x_test.shape,len(y_train),len(y_test)
# Out:
# ((1650, 80, 80, 3), (413, 80, 80, 3), 1650, 413)

# %% [markdown]
# fature extraction
#         [Hog](www.facebook.com)

# %%
img = skimage.io.imread('lion.bmp')
plt.figure(figsize=(6,10))
plt.imshow(img)

# %%
#hog transform
img_re = skimage.transform.rescale(img,1/3).reshape((302,215))
gray = skimage.color.rgb2gray(img_re)
feature_vector, hog_img = skimage.feature.hog(gray,orientations=9,pixels_per_cell=(14,14),
                    cells_per_block=(2,2),visualize=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/4185959224.py:3: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   gray = skimage.color.rgb2gray(img_re)

# %%
len(feature_vector)
# Out:
# 10080

# %%
gray.shape
# Out:
# (302, 215)

# %%
plt.figure(figsize=(12,10))
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(hog_img,cmap='gray')

# %% [markdown]
# ##preprocessing
# > grayscale
# > Hog(histogram oriented gradient)transform

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class rgb2gray_transform(BaseEstimator, TransformerMixin):
    import skimage.color
    
    def __init__(self):
        pass
    def fit(self,X,y=None):
        return self
    def transform(self,X,y=None):
        return np.array([skimage.color.rgb2gray(x) for x in X])

# %%
x_train.shape
# Out:
# (1650, 80, 80, 3)

# %%
rgb2grayobj = rgb2gray_transform()
x_train_gray = rgb2grayobj.fit_transform(x_train)

# %%
x_train_gray.shape
# Out:
# (1650, 80, 80)

# %%
plt.subplot(1,2,1)
plt.imshow(x_train[10])
plt.subplot(1,2,2)
plt.imshow(x_train_gray[10],cmap='gray')

# %% [markdown]
# Hog transformation :-

# %%
class hogtransformer(BaseEstimator, TransformerMixin):
    import skimage.feature
    def __init__(self,orientations=9,pixels_per_cell=(8,8),cells_per_block=(3,3),):
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        def local_hog(img):
            hog_features = skimage.feature.hog(img,orientations=self.orientations,
                                              pixels_per_cell = self.pixels_per_cell,
                                              cells_per_block=self.cells_per_block)
            return hog_features
        hfeatures = np.array([local_hog(x) for x in X])
        return hfeatures

# %%
hogt = hogtransformer()

# %%
x_train_hog = hogt.fit_transform(x_train_gray)

# %%
x_train_hog.shape
# Out:
# (1650, 5184)

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.imshow(x_train[10])
plt.subplot(1,3,2)
plt.imshow(x_train_gray[10],cmap='gray')

# %% [markdown]
# Trainig Machine Learning Model

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
import sklearn.metrics
from sklearn.preprocessing import StandardScaler

# %%
model_sgd = SGDClassifier(loss='hinge',learning_rate='adaptive',
                         early_stopping=True,eta0=0.1)

# %%
x_train.shape,x_test.shape
# Out:
# ((1650, 80, 80, 3), (413, 80, 80, 3))

# %%
grayify = rgb2gray_transform()
hogify = hogtransformer()
scalify = StandardScaler()

# %%
#pipline
#step 1 : convert into grayscale
x_train_gray = grayify.fit_transform(x_train)
#step 2 : extract the features
x_train_hog = hogify.fit_transform(x_train_gray)
#step 3 : Normalization
x_train_scale = scalify.fit_transform(x_train_hog)
#step 4 : mschine learning
model_sgd.fit(x_train_scale, y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
x_test_gray = grayify.fit_transform(x_test)
#step2 : extraction the feature
x_test_hog = hogify.fit_transform(x_test_gray)
#step 3 : Normalization
x_test_scale = scalify.transform(x_test_hog)

y_pred_test = model_sgd.predict(x_test_scale)

# %%
y_pred_test
# Out:
# array(['wolf', 'deer', 'cat', 'panda', 'mouse', 'panda', 'eagle', 'human',
#        'panda', 'human', 'cat', 'human', 'rabbit', 'monkey', 'dog',
#        'elephant', 'pigeon', 'deer', 'monkey', 'eagle', 'elephant',
#        'panda', 'pigeon', 'cat', 'deer', 'duck', 'rabbit', 'lion', 'wolf',
#        'elephant', 'cat', 'pigeon', 'tiger', 'duck', 'mouse', 'mouse',
#        'monkey', 'cat', 'sheep', 'deer', 'deer', 'tiger', 'human',
#        'pigeon', 'pigeon', 'tiger', 'pigeon', 'sheep', 'cow', 'eagle',
#        'wolf', 'panda', 'human', 'lion', 'sheep', 'eagle', 'tiger',
#        'eagle', 'natural', 'sheep', 'eagle', 'lion', 'dog', 'panda',
#        'duck', 'pigeon', 'human', 'rabbit', 'lion', 'sheep', 'rabbit',
#        'chicken', 'cow', 'human', 'natural', 'panda', 'deer', 'cat',
#        'elephant', 'lion', 'cow', 'cat', 'panda', 'elephant', 'pigeon',
#        'human', 'tiger', 'human', 'cat', 'duck', 'lion', 'panda',
#        'rabbit', 'elephant', 'tiger', 'cow', 'mouse', 'cat', 'bear',
#        'cow', 'panda', 'elephant', 'deer', 'duck', 'eagle', 'dog', 'lion',
#        'mouse', 'wolf', 'rabbit', 'rabbit', 'human', 'chicken', 'sheep',
#        'chicken', 'rabbit', 'bear', 'rabbit', 'duck', 'bear', 'cow',
#        'cat', 'mouse', 'dog', 'cow', 'lion', 'tiger', 'natural', 'deer',
#        'deer', 'panda', 'human', 'lion', 'monkey', 'rabbit', 'tiger',
#        'lion', 'lion', 'cat', 'cat', 'cat', 'eagle', 'panda', 'wolf',
#        'panda', 'dog', 'cat', 'chicken', 'sheep', 'duck', 'duck',
#        'monkey', 'panda', 'pigeon', 'dog', 'eagle', 'pigeon', 'wolf',
#        'human', 'deer', 'rabbit', 'cat', 'lion', 'panda', 'cow', 'mouse',
#        'wolf', 'human', 'cat', 'elephant', 'pigeon', 'duck', 'dog',
#        'lion', 'panda', 'human', 'duck', 'duck', 'pigeon', 'cow', 'deer',
#        'deer', 'cat', 'duck', 'cow', 'deer', 'human', 'human', 'rabbit',
#        'sheep', 'panda', 'sheep', 'tiger', 'rabbit', 'eagle', 'rabbit',
#        'panda', 'duck', 'pigeon', 'natural', 'eagle', 'cat', 'panda',
#        'panda', 'lion', 'chicken', 'deer', 'panda', 'pigeon', 'pigeon',
#        'monkey', 'mouse', 'chicken', 'human', 'human', 'sheep', 'human',
#        'wolf', 'deer', 'tiger', 'chicken', 'sheep', 'duck', 'dog',
#        'sheep', 'eagle', 'cow', 'tiger', 'chicken', 'tiger', 'pigeon',
#        'wolf', 'rabbit', 'deer', 'pigeon', 'bear', 'rabbit', 'deer',
#        'sheep', 'human', 'lion', 'rabbit', 'cat', 'monkey', 'deer',
#        'rabbit', 'dog', 'bear', 'duck', 'tiger', 'cow', 'rabbit', 'dog',
#        'wolf', 'monkey', 'lion', 'tiger', 'duck', 'duck', 'duck',
#        'pigeon', 'pigeon', 'cat', 'panda', 'duck', 'tiger', 'human',
#        'dog', 'eagle', 'cat', 'deer', 'duck', 'wolf', 'panda', 'mouse',
#        'cat', 'cow', 'dog', 'eagle', 'bear', 'eagle', 'mouse', 'cat',
#        'deer', 'duck', 'panda', 'pigeon', 'tiger', 'bear', 'deer', 'duck',
#        'rabbit', 'rabbit', 'dog', 'monkey', 'dog', 'duck', 'elephant',
#        'cat', 'tiger', 'panda', 'dog', 'mouse', 'human', 'sheep', 'sheep',
#        'dog', 'panda', 'panda', 'human', 'human', 'natural', 'eagle',
#        'panda', 'sheep', 'tiger', 'lion', 'sheep', 'monkey', 'bear',
#        'cat', 'dog', 'dog', 'dog', 'human', 'cat', 'sheep', 'sheep',
#        'tiger', 'mouse', 'cat', 'panda', 'tiger', 'rabbit', 'deer',
#        'panda', 'duck', 'cat', 'chicken', 'cat', 'bear', 'tiger', 'bear',
#        'dog', 'cow', 'chicken', 'cat', 'monkey', 'pigeon', 'dog',
#        'monkey', 'cat', 'deer', 'dog', 'bear', 'elephant', 'dog', 'cow',
#        'rabbit', 'human', 'mouse', 'human', 'lion', 'tiger', 'monkey',
#        'deer', 'duck', 'human', 'tiger', 'wolf', 'mouse', 'human',
#        'human', 'panda', 'wolf', 'chicken', 'elephant', 'elephant',
#        'wolf', 'panda', 'lion', 'mouse', 'rabbit', 'lion', 'pigeon',
#        'rabbit', 'panda', 'human', 'dog', 'bear', 'dog', 'cat', 'chicken',
#        'pigeon', 'panda', 'cat', 'pigeon', 'deer', 'panda', 'wolf', 'cat',
#        'human', 'eagle', 'dog', 'elephant', 'eagle', 'deer', 'dog',
#        'panda', 'chicken', 'human', 'wolf', 'eagle'], dtype='<U8')

# %% [markdown]
# ### Model Evolution

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.250000  0.150000  0.187500   20.000000
# cat            0.617647  0.656250  0.636364   32.000000
# chicken        0.769231  0.500000  0.606061   20.000000
# cow            0.400000  0.285714  0.333333   21.000000
# deer           0.538462  0.666667  0.595745   21.000000
# dog            0.296296  0.307692  0.301887   26.000000
# duck           0.480000  0.571429  0.521739   21.000000
# eagle          0.578947  0.550000  0.564103   20.000000
# elephant       0.692308  0.450000  0.545455   20.000000
# human          0.606061  0.952381  0.740741   21.000000
# lion           0.400000  0.400000  0.400000   20.000000
# monkey         0.384615  0.250000  0.303030   20.000000
# mouse          0.466667  0.350000  0.400000   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.583333  0.875000  0.700000   24.000000
# pigeon         0.583333  0.608696  0.595745   23.000000
# rabbit         0.520000  0.650000  0.577778   20.000000
# sheep          0.368421  0.350000  0.358974   20.000000
# tiger          0.652174  0.652174  0.652174   23.000000
# wolf           0.687500  0.550000  0.611111   20.000000
# accuracy       0.520581  0.520581  0.520581    0.520581
# macro avg      0.493750  0.488800  0.481587  413.000000
# weighted avg   0.519985  0.520581  0.510455  413.000000

# %%
metrics.cohen_kappa_score(y_test,y_pred_test)
# Out:
# 0.4935026323939301

# %% [markdown]
# Pipeline model

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipe = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer(orientations=8,
                                  pixels_per_cell =(10,10),cells_per_block=(3,3))),
    ('scaler',StandardScaler()),
    ('sgd',SGDClassifier(loss='hinge',learning_rate='adaptive',
                        early_stopping=True,eta0=0.1))
])

# %%
model_pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('grascale', rgb2gray_transform()),
#                 ('hogtransform',
#                  hogtransformer(orientations=8, pixels_per_cell=(10, 10))),
#                 ('scaler', StandardScaler()),
#                 ('sgd',
#                  SGDClassifier(early_stopping=True, eta0=0.1,
#                                learning_rate='adaptive'))])

# %%
y_pred_test = model_pipe.predict(x_test)

# %%
y_pred_test
# Out:
# array(['dog', 'deer', 'cat', 'panda', 'mouse', 'panda', 'eagle', 'human',
#        'tiger', 'human', 'wolf', 'wolf', 'rabbit', 'monkey', 'rabbit',
#        'cat', 'pigeon', 'mouse', 'lion', 'eagle', 'elephant', 'panda',
#        'elephant', 'bear', 'sheep', 'duck', 'rabbit', 'sheep', 'wolf',
#        'elephant', 'monkey', 'dog', 'tiger', 'mouse', 'mouse', 'deer',
#        'wolf', 'cat', 'sheep', 'sheep', 'deer', 'tiger', 'human',
#        'pigeon', 'pigeon', 'tiger', 'pigeon', 'sheep', 'mouse', 'monkey',
#        'lion', 'panda', 'monkey', 'cat', 'lion', 'panda', 'cow', 'rabbit',
#        'duck', 'sheep', 'eagle', 'wolf', 'dog', 'panda', 'tiger', 'mouse',
#        'human', 'sheep', 'sheep', 'pigeon', 'cow', 'chicken', 'cow',
#        'monkey', 'tiger', 'panda', 'chicken', 'cow', 'elephant', 'monkey',
#        'sheep', 'cat', 'panda', 'elephant', 'pigeon', 'human', 'tiger',
#        'monkey', 'cat', 'chicken', 'pigeon', 'cat', 'rabbit', 'elephant',
#        'tiger', 'dog', 'cat', 'cat', 'human', 'cow', 'panda', 'duck',
#        'duck', 'duck', 'eagle', 'elephant', 'dog', 'mouse', 'cat',
#        'mouse', 'rabbit', 'human', 'chicken', 'dog', 'chicken', 'rabbit',
#        'wolf', 'rabbit', 'duck', 'wolf', 'monkey', 'cat', 'tiger', 'cat',
#        'cow', 'lion', 'elephant', 'mouse', 'deer', 'mouse', 'pigeon',
#        'dog', 'lion', 'chicken', 'lion', 'dog', 'lion', 'lion', 'cat',
#        'elephant', 'cat', 'pigeon', 'cow', 'pigeon', 'panda', 'human',
#        'cow', 'rabbit', 'sheep', 'duck', 'duck', 'rabbit', 'mouse', 'dog',
#        'dog', 'duck', 'eagle', 'wolf', 'dog', 'deer', 'tiger', 'elephant',
#        'elephant', 'bear', 'pigeon', 'mouse', 'wolf', 'human', 'tiger',
#        'elephant', 'panda', 'duck', 'dog', 'lion', 'deer', 'human',
#        'duck', 'eagle', 'pigeon', 'sheep', 'deer', 'deer', 'duck', 'bear',
#        'cow', 'deer', 'human', 'human', 'rabbit', 'deer', 'panda',
#        'sheep', 'dog', 'bear', 'elephant', 'rabbit', 'pigeon', 'rabbit',
#        'pigeon', 'human', 'chicken', 'cat', 'pigeon', 'panda', 'lion',
#        'tiger', 'deer', 'cat', 'elephant', 'sheep', 'cat', 'pigeon',
#        'chicken', 'human', 'cat', 'dog', 'human', 'wolf', 'deer', 'tiger',
#        'chicken', 'sheep', 'duck', 'monkey', 'lion', 'eagle', 'cat',
#        'tiger', 'chicken', 'tiger', 'pigeon', 'wolf', 'elephant',
#        'rabbit', 'pigeon', 'cat', 'rabbit', 'deer', 'bear', 'monkey',
#        'lion', 'panda', 'deer', 'dog', 'rabbit', 'cat', 'mouse', 'cow',
#        'human', 'lion', 'deer', 'eagle', 'dog', 'dog', 'cat', 'lion',
#        'bear', 'lion', 'wolf', 'eagle', 'pigeon', 'pigeon', 'cat',
#        'monkey', 'tiger', 'tiger', 'human', 'deer', 'eagle', 'cat',
#        'deer', 'duck', 'cat', 'sheep', 'bear', 'cat', 'pigeon',
#        'elephant', 'eagle', 'elephant', 'cat', 'monkey', 'cat', 'deer',
#        'cat', 'lion', 'sheep', 'tiger', 'bear', 'deer', 'cat', 'rabbit',
#        'monkey', 'deer', 'monkey', 'dog', 'duck', 'dog', 'cat', 'tiger',
#        'pigeon', 'dog', 'sheep', 'cat', 'sheep', 'monkey', 'dog', 'cow',
#        'panda', 'bear', 'monkey', 'wolf', 'eagle', 'panda', 'bear',
#        'pigeon', 'deer', 'eagle', 'tiger', 'dog', 'panda', 'deer', 'dog',
#        'panda', 'human', 'dog', 'elephant', 'eagle', 'tiger', 'mouse',
#        'cat', 'panda', 'tiger', 'rabbit', 'mouse', 'duck', 'mouse', 'cat',
#        'chicken', 'cat', 'bear', 'tiger', 'wolf', 'dog', 'cow', 'lion',
#        'cow', 'rabbit', 'sheep', 'cat', 'monkey', 'wolf', 'deer', 'dog',
#        'cow', 'chicken', 'cow', 'pigeon', 'bear', 'human', 'monkey',
#        'human', 'lion', 'tiger', 'pigeon', 'wolf', 'rabbit', 'human',
#        'eagle', 'wolf', 'lion', 'human', 'bear', 'panda', 'wolf',
#        'rabbit', 'monkey', 'elephant', 'lion', 'tiger', 'lion', 'mouse',
#        'eagle', 'monkey', 'sheep', 'bear', 'panda', 'monkey', 'lion',
#        'bear', 'dog', 'cat', 'chicken', 'pigeon', 'panda', 'cat', 'eagle',
#        'elephant', 'panda', 'pigeon', 'natural', 'lion', 'duck', 'sheep',
#        'lion', 'pigeon', 'rabbit', 'wolf', 'bear', 'chicken', 'human',
#        'wolf', 'monkey'], dtype='<U8')

# %%
cr = pd.DataFrame(sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)).T
cr
# Out:
#               precision    recall  f1-score     support
# bear           0.562500  0.450000  0.500000   20.000000
# cat            0.552632  0.656250  0.600000   32.000000
# chicken        0.785714  0.550000  0.647059   20.000000
# cow            0.533333  0.380952  0.444444   21.000000
# deer           0.652174  0.714286  0.681818   21.000000
# dog            0.444444  0.461538  0.452830   26.000000
# duck           0.588235  0.476190  0.526316   21.000000
# eagle          0.647059  0.550000  0.594595   20.000000
# elephant       0.600000  0.600000  0.600000   20.000000
# human          0.826087  0.904762  0.863636   21.000000
# lion           0.458333  0.550000  0.500000   20.000000
# monkey         0.500000  0.550000  0.523810   20.000000
# mouse          0.352941  0.300000  0.324324   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.826087  0.791667  0.808511   24.000000
# pigeon         0.535714  0.652174  0.588235   23.000000
# rabbit         0.545455  0.600000  0.571429   20.000000
# sheep          0.523810  0.550000  0.536585   20.000000
# tiger          0.800000  0.869565  0.833333   23.000000
# wolf           0.550000  0.550000  0.550000   20.000000
# accuracy       0.590799  0.590799  0.590799    0.590799
# macro avg      0.564226  0.557869  0.557346  413.000000
# weighted avg   0.592978  0.590799  0.588064  413.000000

# %% [markdown]
# ## Grid Search
# . HyperParrameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer()),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier())
])

# %%
param_grid = [
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['optimal']  
    },
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' :['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['adaptive'],
        'sgd__eta0':[0.001,0.01]
    }
]

# %%
model_grid = GridSearchCV(estimator,
                         param_grid=param_grid,scoring='accuracy',n_jobs=1,
                          cv=3,verbose=2)

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
#   File "D:\program_files\anaconda\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 303, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "D:\program_files\anaconda\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "D:\program_files\anaconda\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_7664/3625266369.py", line 13, in local_hog
#     hog_features = skimage.feature.hog(img,orientations=self.orientations,
# ...
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  22.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  22.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  22.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  21.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  21.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  21.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  21.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  19.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  21.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  24.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  22.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  18.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  13.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  13.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  13.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  12.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  14.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  14.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  14.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  14.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  14.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  14.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   7.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   7.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   7.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  11.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  10.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   9.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  10.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  10.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  10.3s
# D:\program_files\anaconda\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.69030303 0.68666667 0.68606061
#  0.71636364 0.72181818 0.71939394 0.68787879 0.68484848 0.68060606
#  0.68969697 0.68484848 0.68242424 0.7230303  0.72121212 0.71636364
#  0.68727273 0.67393939 0.68              nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.66787879 0.6630303  0.6630303  0.72424242 0.71515152 0.71030303
#  0.67939394 0.68121212 0.68424242 0.67272727 0.66787879 0.65939394
#  0.71333333 0.72121212 0.70909091 0.66606061 0.67333333 0.6769697
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.52606061 0.44484848 0.48484848 0.49515152 0.49454545 0.49090909
#  0.57333333 0.46242424 0.52121212 0.54545455 0.52666667 0.53151515
#  0.56060606 0.1969697  0.50848485 0.51212121 0.48606061 0.5
#  0.54545455 0.45757576 0.49333333 0.50060606 0.47212121 0.4969697
#  0.56666667 0.5030303  0.51636364 0.5369697  0.51515152 0.53212121
#  0.54121212 0.24727273 0.48181818 0.49878788 0.49151515 0.48969697
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.52787879 0.51030303 0.49333333 0.50727273 0.5030303  0.49818182
#  0.56848485 0.52969697 0.54787879 0.53454545 0.53939394 0.53878788
#  0.56606061 0.47272727 0.52424242 0.52121212 0.50181818 0.51030303
#  0.52606061 0.5169697  0.51878788 0.51090909 0.51878788 0.53454545
#  0.54121212 0.52424242 0.53272727 0.54060606 0.52363636 0.53272727
#  0.55757576 0.46424242 0.4830303  0.51212121 0.50787879 0.51090909]
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('grascale', rgb2gray_transform()),
#                                        ('hogtransform', hogtransformer()),
#                                        ('scale', StandardScaler()),
#                                        ('sgd', SGDClassifier())]),
#              n_jobs=1,
#              param_grid=[{'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__learning_rate': ['optimal'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']},
#                          {'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__eta0': [0.001, 0.01],
#                           'sgd__learning_rate': ['adaptive'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']}],
#              scoring='accuracy', verbose=2)

# %%
estimator.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'grascale', 'hogtransform', 'scale', 'sgd', 'hogtransform__cells_per_block', 'hogtransform__orientations', 'hogtransform__pixels_per_cell', 'scale__copy', 'scale__with_mean', 'scale__with_std', 'sgd__alpha', 'sgd__average', 'sgd__class_weight', 'sgd__early_stopping', 'sgd__epsilon', 'sgd__eta0', 'sgd__fit_intercept', 'sgd__l1_ratio', 'sgd__learning_rate', 'sgd__loss', 'sgd__max_iter', 'sgd__n_iter_no_change', 'sgd__n_jobs', 'sgd__penalty', 'sgd__power_t', 'sgd__random_state', 'sgd__shuffle', 'sgd__tol', 'sgd__validation_fraction', 'sgd__verbose', 'sgd__warm_start'])

# %%
model_grid.best_params_
# Out:
# {'hogtransform__cells_per_block': (3, 3),
#  'hogtransform__orientations': 9,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
model_grid.best_score_
# Out:
# 0.7242424242424242

# %%
model_best = model_grid.best_estimator_

# %%
y_pred = model_best.predict(x_test)

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
# D:\program_files\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\program_files\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\program_files\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.750000  0.600000  0.666667   20.000000
# cat            0.725000  0.906250  0.805556   32.000000
# chicken        0.909091  0.500000  0.645161   20.000000
# cow            0.588235  0.476190  0.526316   21.000000
# deer           0.703704  0.904762  0.791667   21.000000
# dog            0.629630  0.653846  0.641509   26.000000
# duck           0.888889  0.761905  0.820513   21.000000
# eagle          0.681818  0.750000  0.714286   20.000000
# elephant       0.695652  0.800000  0.744186   20.000000
# human          1.000000  1.000000  1.000000   21.000000
# lion           0.566667  0.850000  0.680000   20.000000
# monkey         0.650000  0.650000  0.650000   20.000000
# mouse          0.736842  0.700000  0.717949   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.888889  1.000000  0.941176   24.000000
# pigeon         0.791667  0.826087  0.808511   23.000000
# rabbit         1.000000  0.600000  0.750000   20.000000
# sheep          0.684211  0.650000  0.666667   20.000000
# tiger          0.826087  0.826087  0.826087   23.000000
# wolf           0.823529  0.700000  0.756757   20.000000
# accuracy       0.750605  0.750605  0.750605    0.750605
# macro avg      0.726996  0.707756  0.707650  413.000000
# weighted avg   0.762386  0.750605  0.746690  413.000000

# %%
#save the model
pickle.dump(model_best,open('pickle files/dsa_model_best.pickle','wb'))

# %% [markdown]
# ## make pipeline
# {'hogtransform__cells_per_block': (3, 3),
#  'hogtransform__orientations': 9,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
from sklearn.pipeline import make_pipeline

# %%
 pipeline1 = make_pipeline(rgb2gray_transform(),
    hogtransformer(orientations=10,
                   pixels_per_cell=(8,8),
                   cells_per_block=(2,2)))

# %%
feature_vector = pipeline1.fit_transform(x_train)

# %%
#standard scaler
scalar = StandardScaler()
transformed_xtrain = scalar.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal',loss='hinge',alpha=0.01,early_stopping=True)

# %%
model.fit(transformed_xtrain,y_train)
# Out:
# SGDClassifier(alpha=0.01, early_stopping=True)

# %%
#evaluating model
feature_vector = pipeline1.fit_transform(x_test)
transformed_x = scalar.transform(feature_vector)
y_pred_test = model.predict(transformed_x)

# %%
cr = pd.DataFrame(metrics.classification_report(y_test,y_pred_test,output_dict=True)).T
cr
# Out:
# D:\program_files\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\program_files\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\program_files\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.764706  0.650000  0.702703   20.000000
# cat            0.729730  0.843750  0.782609   32.000000
# chicken        0.928571  0.650000  0.764706   20.000000
# cow            0.600000  0.428571  0.500000   21.000000
# deer           0.740741  0.952381  0.833333   21.000000
# dog            0.526316  0.769231  0.625000   26.000000
# duck           0.882353  0.714286  0.789474   21.000000
# eagle          0.750000  0.750000  0.750000   20.000000
# elephant       0.761905  0.800000  0.780488   20.000000
# human          0.952381  0.952381  0.952381   21.000000
# lion           0.500000  0.750000  0.600000   20.000000
# monkey         0.714286  0.750000  0.731707   20.000000
# mouse          0.789474  0.750000  0.769231   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.846154  0.916667  0.880000   24.000000
# pigeon         0.750000  0.782609  0.765957   23.000000
# rabbit         0.769231  0.500000  0.606061   20.000000
# sheep          0.769231  0.500000  0.606061   20.000000
# tiger          0.791667  0.826087  0.808511   23.000000
# wolf           0.812500  0.650000  0.722222   20.000000
# accuracy       0.738499  0.738499  0.738499    0.738499
# macro avg      0.718962  0.696798  0.698522  413.000000
# weighted avg   0.752263  0.738499  0.735760  413.000000

# %%
#save models for flask app
pickle.dump(model,open('pickle files/dsa_image_classification_sgd.pickle','wb'))

# %%
pickle.dump(scalar,open('pickle files/dsa_scaler.pickle','wb'))
