# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
import skimage
import skimage.color
import skimage.io
import skimage.feature
import skimage.transform

# %%
#Load the data
data = pickle.load(open('pickle files/data_animals_head_20.pickle','rb'))

# %%
data['description']
# Out:
# 'There are 20 classes and 2057 images. All the images are 80 x 80 (rgb)'

# %%
#split the data into independent and dependent
X = data['data'] #indepemdent
y = data['target'] #dependent

# %%
# Out:
# (array([[[[196, 214, 188],
#          [196, 214, 188],
#          [196, 214, 188],
#          ...,
#          [ 81,  76,  80],
#          [ 81,  76,  80],
#          [ 69,  64,  68]],
#
#         [[196, 214, 188],
#          [196, 214, 188],
#          [196, 215, 187],
#          ...,
#          [ 82,  77,  81],
#          [ 83,  78,  82],
#          [ 77,  72,  76]],
#
#         [[193, 213, 185],
#          [194, 214, 186],
#          [194, 214, 186],
#          ...,
#          [ 82,  77,  81],
#          [ 81,  76,  80],
#          [ 78,  73,  77]],
#
#         ...,
#
#         [[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [ 70,  65,  69],
#          [ 65,  60,  64],
#          [ 62,  57,  63]],
#
#         [[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [ 66,  61,  65],
#          [ 62,  57,  61],
#          [ 64,  59,  65]],
#
#         [[254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [ 56,  51,  55],
#          [ 79,  74,  78],
#          [ 70,  63,  70]]],
#
#
#        [[[  4,   2,   3],
#          [  7,   5,   6],
#          [  6,   5,   3],
#          ...,
#          [ 42,  31,  25],
#          [ 46,  35,  29],
#          [ 45,  32,  26]],
#
#         [[  7,   5,   6],
#          [  5,   4,   2],
#          [  2,   1,   0],
#          ...,
#          [ 22,  11,   5],
#          [ 43,  32,  26],
#          [ 47,  36,  30]],
#
#         [[  6,   5,   3],
#          [  3,   2,   0],
#          [  2,   1,   0],
#          ...,
#          [ 33,  24,  17],
#          [ 48,  39,  32],
#          [ 54,  45,  38]],
#
#         ...,
#
#         [[ 24,  29,   6],
#          [ 24,  30,   4],
#          [ 25,  31,   5],
#          ...,
#          [116, 116,  80],
#          [115, 117,  80],
#          [127, 129,  92]],
#
#         [[ 22,  27,   4],
#          [ 23,  28,   5],
#          [ 24,  29,   6],
#          ...,
#          [112, 112,  76],
#          [115, 117,  80],
#          [128, 130,  93]],
#
#         [[ 22,  27,   5],
#          [ 22,  27,   4],
#          [ 22,  27,   4],
#          ...,
#          [106, 106,  70],
#          [112, 114,  77],
#          [126, 128,  91]]],
#
#
#        [[[104, 109, 102],
#          [104, 111, 103],
#          [108, 115, 107],
#          ...,
#          [130, 126, 127],
#          [122, 117, 121],
#          [123, 118, 122]],
#
#         [[113, 118, 111],
#          [ 97, 104,  96],
#          [103, 110, 102],
#          ...,
#          [111, 107, 108],
#          [129, 124, 128],
#          [150, 145, 149]],
#
#         [[126, 133, 125],
#          [112, 119, 111],
#          [110, 117, 109],
#          ...,
#          [139, 135, 136],
#          [162, 157, 161],
#          [163, 158, 162]],
#
#         ...,
#
#         [[214, 214, 202],
#          [206, 206, 194],
#          [202, 200, 187],
#          ...,
#          [164, 162, 150],
#          [173, 173, 163],
#          [187, 187, 179]],
#
#         [[219, 219, 207],
#          [210, 210, 198],
#          [205, 203, 190],
#          ...,
#          [170, 168, 156],
#          [174, 174, 164],
#          [188, 188, 180]],
#
#         [[214, 214, 202],
#          [201, 201, 189],
#          [198, 196, 183],
#          ...,
#          [172, 170, 158],
#          [179, 179, 169],
#          [184, 184, 176]]],
#
#
#        ...,
#
#
#        [[[147, 154, 113],
#          [145, 152, 111],
#          [146, 153, 112],
#          ...,
#          [102, 109,  58],
#          [118, 121,  74],
#          [128, 131,  86]],
#
#         [[148, 155, 114],
#          [146, 153, 112],
#          [145, 152, 111],
#          ...,
#          [120, 128,  71],
#          [138, 142,  91],
#          [151, 155, 105]],
#
#         [[147, 154, 112],
#          [146, 153, 111],
#          [144, 151, 109],
#          ...,
#          [136, 142,  80],
#          [143, 151,  91],
#          [150, 158,  99]],
#
#         ...,
#
#         [[137, 142,  88],
#          [146, 150,  99],
#          [145, 148, 101],
#          ...,
#          [143, 138, 100],
#          [148, 143, 103],
#          [158, 150, 111]],
#
#         [[133, 138,  82],
#          [128, 133,  79],
#          [129, 133,  83],
#          ...,
#          [158, 153, 115],
#          [157, 152, 112],
#          [154, 149, 109]],
#
#         [[130, 135,  79],
#          [128, 133,  79],
#          [135, 139,  88],
#          ...,
#          [160, 155, 115],
#          [157, 152, 112],
#          [150, 145, 105]]],
#
#
#        [[[246, 250, 249],
#          [247, 251, 250],
#          [252, 254, 253],
#          ...,
#          [136, 118, 114],
#          [143, 124, 118],
#          [145, 126, 120]],
#
#         [[244, 248, 247],
#          [252, 255, 255],
#          [243, 245, 244],
#          ...,
#          [139, 124, 117],
#          [135, 120, 113],
#          [156, 141, 134]],
#
#         [[238, 242, 241],
#          [248, 252, 251],
#          [246, 248, 247],
#          ...,
#          [128, 118, 109],
#          [128, 118, 109],
#          [141, 131, 122]],
#
#         ...,
#
#         [[236, 233, 224],
#          [230, 226, 217],
#          [228, 224, 215],
#          ...,
#          [159, 142, 126],
#          [152, 135, 119],
#          [150, 133, 117]],
#
#         [[234, 231, 222],
#          [233, 230, 221],
#          [229, 225, 216],
#          ...,
#          [185, 169, 154],
#          [165, 149, 134],
#          [169, 153, 138]],
#
#         [[242, 239, 232],
#          [236, 233, 224],
#          [229, 225, 216],
#          ...,
#          [193, 177, 162],
#          [185, 169, 154],
#          [175, 159, 144]]],
#
#
#        [[[ 85,  78,  32],
#          [ 79,  72,  26],
#          [ 79,  72,  26],
#          ...,
#          [ 80,  73,  27],
#          [ 76,  69,  23],
#          [ 74,  67,  21]],
#
#         [[ 82,  78,  31],
#          [ 79,  72,  26],
#          [ 78,  71,  25],
#          ...,
#          [ 78,  71,  25],
#          [ 75,  68,  24],
#          [ 71,  64,  20]],
#
#         [[ 81,  77,  30],
#          [ 80,  73,  27],
#          [ 77,  70,  24],
#          ...,
#          [ 78,  71,  27],
#          [ 76,  69,  25],
#          [ 71,  64,  20]],
#
#         ...,
#
#         [[ 85,  55,  17],
#          [ 92,  60,  22],
#          [ 90,  58,  20],
#          ...,
#          [103, 101,  53],
#          [ 99,  97,  49],
#          [ 96,  94,  46]],
#
#         [[ 87,  57,  19],
#          [ 82,  50,  11],
#          [ 88,  56,  17],
#          ...,
#          [104, 100,  53],
#          [101,  97,  50],
#          [ 98,  94,  47]],
#
#         [[ 82,  53,  13],
#          [ 83,  51,  12],
#          [ 92,  60,  21],
#          ...,
#          [101,  94,  48],
#          [100,  93,  47],
#          [ 98,  91,  45]]]], dtype=uint8), ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer' ...

# %%
print(X)
# Out:
# [[[[196 214 188]
#    [196 214 188]
#    [196 214 188]
#    ...
#    [ 81  76  80]
#    [ 81  76  80]
#    [ 69  64  68]]
#
#   [[196 214 188]
#    [196 214 188]
#    [196 215 187]
#    ...
#    [ 82  77  81]
#    [ 83  78  82]
#    [ 77  72  76]]
#
#   [[193 213 185]
#    [194 214 186]
#    [194 214 186]
#    ...
#    [ 82  77  81]
#    [ 81  76  80]
#    [ 78  73  77]]
#
#   ...
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 70  65  69]
#    [ 65  60  64]
#    [ 62  57  63]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 66  61  65]
#    [ 62  57  61]
#    [ 64  59  65]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 56  51  55]
#    [ 79  74  78]
#    [ 70  63  70]]]
#
#
#  [[[  4   2   3]
#    [  7   5   6]
#    [  6   5   3]
#    ...
#    [ 42  31  25]
#    [ 46  35  29]
#    [ 45  32  26]]
#
#   [[  7   5   6]
#    [  5   4   2]
#    [  2   1   0]
#    ...
#    [ 22  11   5]
#    [ 43  32  26]
#    [ 47  36  30]]
#
#   [[  6   5   3]
#    [  3   2   0]
#    [  2   1   0]
#    ...
#    [ 33  24  17]
#    [ 48  39  32]
#    [ 54  45  38]]
#
#   ...
#
#   [[ 24  29   6]
#    [ 24  30   4]
#    [ 25  31   5]
#    ...
#    [116 116  80]
#    [115 117  80]
#    [127 129  92]]
#
#   [[ 22  27   4]
#    [ 23  28   5]
#    [ 24  29   6]
#    ...
#    [112 112  76]
#    [115 117  80]
#    [128 130  93]]
#
#   [[ 22  27   5]
#    [ 22  27   4]
#    [ 22  27   4]
#    ...
#    [106 106  70]
#    [112 114  77]
#    [126 128  91]]]
#
#
#  [[[104 109 102]
#    [104 111 103]
#    [108 115 107]
#    ...
#    [130 126 127]
#    [122 117 121]
#    [123 118 122]]
#
#   [[113 118 111]
#    [ 97 104  96]
#    [103 110 102]
#    ...
#    [111 107 108]
#    [129 124 128]
#    [150 145 149]]
#
#   [[126 133 125]
#    [112 119 111]
#    [110 117 109]
#    ...
#    [139 135 136]
#    [162 157 161]
#    [163 158 162]]
#
#   ...
#
#   [[214 214 202]
#    [206 206 194]
#    [202 200 187]
#    ...
#    [164 162 150]
#    [173 173 163]
#    [187 187 179]]
#
#   [[219 219 207]
#    [210 210 198]
#    [205 203 190]
#    ...
#    [170 168 156]
#    [174 174 164]
#    [188 188 180]]
#
#   [[214 214 202]
#    [201 201 189]
#    [198 196 183]
#    ...
#    [172 170 158]
#    [179 179 169]
#    [184 184 176]]]
#
#
#  ...
#
#
#  [[[147 154 113]
#    [145 152 111]
#    [146 153 112]
#    ...
#    [102 109  58]
#    [118 121  74]
#    [128 131  86]]
#
#   [[148 155 114]
#    [146 153 112]
#    [145 152 111]
#    ...
#    [120 128  71]
#    [138 142  91]
#    [151 155 105]]
#
#   [[147 154 112]
#    [146 153 111]
#    [144 151 109]
#    ...
#    [136 142  80]
#    [143 151  91]
#    [150 158  99]]
#
#   ...
#
#   [[137 142  88]
#    [146 150  99]
#    [145 148 101]
#    ...
#    [143 138 100]
#    [148 143 103]
#    [158 150 111]]
#
#   [[133 138  82]
#    [128 133  79]
#    [129 133  83]
#    ...
#    [158 153 115]
#    [157 152 112]
#    [154 149 109]]
#
#   [[130 135  79]
#    [128 133  79]
#    [135 139  88]
#    ...
#    [160 155 115]
#    [157 152 112]
#    [150 145 105]]]
#
#
#  [[[246 250 249]
#    [247 251 250]
#    [252 254 253]
#    ...
#    [136 118 114]
#    [143 124 118]
#    [145 126 120]]
#
#   [[244 248 247]
#    [252 255 255]
#    [243 245 244]
#    ...
#    [139 124 117]
#    [135 120 113]
#    [156 141 134]]
#
#   [[238 242 241]
#    [248 252 251]
#    [246 248 247]
#    ...
#    [128 118 109]
#    [128 118 109]
#    [141 131 122]]
#
#   ...
#
#   [[236 233 224]
#    [230 226 217]
#    [228 224 215]
#    ...
#    [159 142 126]
#    [152 135 119]
#    [150 133 117]]
#
#   [[234 231 222]
#    [233 230 221]
#    [229 225 216]
#    ...
#    [185 169 154]
#    [165 149 134]
#    [169 153 138]]
#
#   [[242 239 232]
#    [236 233 224]
#    [229 225 216]
#    ...
#    [193 177 162]
#    [185 169 154]
#    [175 159 144]]]
#
#
#  [[[ 85  78  32]
#    [ 79  72  26]
#    [ 79  72  26]
#    ...
#    [ 80  73  27]
#    [ 76  69  23]
#    [ 74  67  21]]
#
#   [[ 82  78  31]
#    [ 79  72  26]
#    [ 78  71  25]
#    ...
#    [ 78  71  25]
#    [ 75  68  24]
#    [ 71  64  20]]
#
#   [[ 81  77  30]
#    [ 80  73  27]
#    [ 77  70  24]
#    ...
#    [ 78  71  27]
#    [ 76  69  25]
#    [ 71  64  20]]
#
#   ...
#
#   [[ 85  55  17]
#    [ 92  60  22]
#    [ 90  58  20]
#    ...
#    [103 101  53]
#    [ 99  97  49]
#    [ 96  94  46]]
#
#   [[ 87  57  19]
#    [ 82  50  11]
#    [ 88  56  17]
#    ...
#    [104 100  53]
#    [101  97  50]
#    [ 98  94  47]]
#
#   [[ 82  53  13]
#    [ 83  51  12]
#    [ 92  60  21]
#    ...
#    [101  94  48]
#    [100  93  47]
#    [ 98  91  45]]]]

# %%
print(y)
# Out:
# ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', ' ...

# %%
#split the data into train and test
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %%
x_train.shape,x_test.shape,len(y_train),len(y_test)
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3), 1645, 412)

# %% [markdown]
# fature extraction
#         [Hog](www.facebook.com)

# %%
ls
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is 0EDE-FBE6
#
#  Directory of D:\DOWNLOADS\Deploy End to End Machine Learning Web App in Cloud Platform\[TutsNode.com] - Deploy End to End Machine Learning Web App in Cloud Platform\3. Image Data Preparation\1.1 dataprepare_machinelearning_pipeline
#
# 12-08-2021  07:53 PM    <DIR>          .
# 12-08-2021  07:53 PM    <DIR>          ..
# 12-08-2021  05:40 PM    <DIR>          .ipynb_checkpoints
# 02-02-2021  09:17 PM           544,893 1. Data preparation.ipynb
# 16-05-2021  02:18 AM               147 1. Download the Resources.html
# 12-08-2021  05:40 PM         1,448,212 2. Machine Learning.ipynb
# 12-02-2021  09:15 PM            39,361 3-make pipeline.ipynb
# 11-08-2021  03:21 PM           566,208 a. data prepration.ipynb
# 23-02-2021  11:50 PM    <DIR>          data
# 11-08-2021  03:21 PM        39,524,530 data_animals_head_20.pickle
# 11-08-2021  04:42 PM    <DIR>          Images
# 02-02-2021  09:41 PM           122,337 lion.bmp
# 23-02-2021  11:50 PM    <DIR>          pickle_files
# 12-08-2021  07:53 PM           939,626 Untitled.ipynb
#                8 File(s)     43,185,314 bytes
#                6 Dir(s)  159,614,054,400 bytes free

# %%
img = skimage.io.imread('lion.bmp')
plt.figure(figsize=(6,10))
plt.imshow(img)

# %%
#hog transform
img_re = skimage.transform.rescale(img,1/3).reshape((302,215))
gray = skimage.color.rgb2gray(img_re)
feature_vector, hog_img = skimage.feature.hog(gray,orientations=9,pixels_per_cell=(14,14),
                    cells_per_block=(2,2),visualize=True)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(feature_vector)
# Out:
# 10080

# %%
gray.shape
# Out:
# (302, 215)

# %%
plt.figure(figsize=(12,10))
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(hog_img,cmap='gray')

# %% [markdown]
# ##preprocessing
# > grayscale
# > Hog(histogram oriented gradient)transform

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class rgb2gray_transform(BaseEstimator, TransformerMixin):
    import skimage.color
    
    def __init__(self):
        pass
    def fit(self,X,y=None):
        return self
    def transform(self,X,y=None):
        return np.array([skimage.color.rgb2gray(x) for x in X])

# %%
x_train.shape
# Out:
# (1645, 80, 80, 3)

# %%
rgb2grayobj = rgb2gray_transform()
x_train_gray = rgb2grayobj.fit_transform(x_train)

# %%
x_train_gray.shape
# Out:
# (1645, 80, 80)

# %%
plt.subplot(1,2,1)
plt.imshow(x_train[10])
plt.subplot(1,2,2)
plt.imshow(x_train_gray[10],cmap='gray')

# %% [markdown]
# Hog transformation :-

# %%
class hogtransformer(BaseEstimator, TransformerMixin):
    import skimage.feature
    def __init__(self,orientations=9,pixels_per_cell=(8,8),cells_per_block=(3,3),):
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        def local_hog(img):
            hog_features = skimage.feature.hog(img,orientations=self.orientations,
                                              pixels_per_cell = self.pixels_per_cell,
                                              cells_per_block=self.cells_per_block)
            return hog_features
        hfeatures = np.array([local_hog(x) for x in X])
        return hfeatures

# %%
hogt = hogtransformer()

# %%
x_train_hog = hogt.fit_transform(x_train_gray)

# %%
x_train_hog.shape
# Out:
# (1645, 5184)

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.imshow(x_train[10])
plt.subplot(1,3,2)
plt.imshow(x_train_gray[10],cmap='gray')

# %% [markdown]
# Trainig Machine Learning Model

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
import sklearn.metrics
from sklearn.preprocessing import StandardScaler

# %%
model_sgd = SGDClassifier(loss='hinge',learning_rate='adaptive',
                         early_stopping=True,eta0=0.1)

# %%
x_train.shape,x_test.shape
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3))

# %%
grayify = rgb2gray_transform()
hogify = hogtransformer()
scalify = StandardScaler()

# %%
#pipline
#step 1 : convert into grayscale
x_train_gray = grayify.fit_transform(x_train)
#step 2 : extract the features
x_train_hog = hogify.fit_transform(x_train_gray)
#step 3 : Normalization
x_train_scale = scalify.fit_transform(x_train_hog)
#step 4 : mschine learning
model_sgd.fit(x_train_scale, y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
x_test_gray = grayify.fit_transform(x_test)
#step2 : extraction the feature
x_test_hog = hogify.fit_transform(x_test_gray)
#step 3 : Normalization
x_test_scale = scalify.transform(x_test_hog)

y_pred_test = model_sgd.predict(x_test_scale)

# %%
y_pred_test
# Out:
# array(['cat', 'tiger', 'tiger', 'bear', 'sheep', 'human', 'lion', 'panda',
#        'chicken', 'elephant', 'dog', 'tiger', 'pigeon', 'mouse', 'tiger',
#        'tiger', 'human', 'panda', 'deer', 'duck', 'panda', 'duck',
#        'tiger', 'lion', 'monkey', 'rabbit', 'monkey', 'chicken', 'cat',
#        'elephant', 'wolf', 'pigeon', 'bear', 'monkey', 'eagle',
#        'elephant', 'human', 'tiger', 'deer', 'deer', 'lion', 'duck',
#        'wolf', 'monkey', 'wolf', 'panda', 'cat', 'rabbit', 'eagle',
#        'human', 'cat', 'rabbit', 'tiger', 'deer', 'panda', 'sheep', 'cow',
#        'tiger', 'tiger', 'panda', 'dog', 'chicken', 'monkey', 'duck',
#        'cat', 'chicken', 'lion', 'lion', 'rabbit', 'rabbit', 'tiger',
#        'cat', 'tiger', 'bear', 'wolf', 'monkey', 'pigeon', 'monkey',
#        'panda', 'duck', 'dog', 'rabbit', 'sheep', 'panda', 'cat',
#        'elephant', 'chicken', 'rabbit', 'human', 'eagle', 'pigeon',
#        'bear', 'monkey', 'pigeon', 'chicken', 'wolf', 'dog', 'cow',
#        'panda', 'tiger', 'sheep', 'deer', 'lion', 'panda', 'pigeon',
#        'monkey', 'duck', 'bear', 'cat', 'human', 'bear', 'wolf', 'dog',
#        'cow', 'eagle', 'chicken', 'duck', 'tiger', 'duck', 'human',
#        'duck', 'wolf', 'wolf', 'monkey', 'sheep', 'cat', 'bear', 'dog',
#        'bear', 'cat', 'wolf', 'pigeon', 'monkey', 'eagle', 'mouse',
#        'duck', 'chicken', 'eagle', 'elephant', 'duck', 'pigeon', 'mouse',
#        'eagle', 'pigeon', 'human', 'panda', 'panda', 'wolf', 'pigeon',
#        'cow', 'eagle', 'elephant', 'eagle', 'cat', 'human', 'elephant',
#        'human', 'dog', 'rabbit', 'monkey', 'tiger', 'human', 'mouse',
#        'elephant', 'cat', 'chicken', 'dog', 'monkey', 'lion', 'bear',
#        'cat', 'dog', 'duck', 'cow', 'human', 'cow', 'cow', 'tiger',
#        'panda', 'panda', 'mouse', 'panda', 'elephant', 'sheep', 'panda',
#        'wolf', 'mouse', 'cow', 'pigeon', 'deer', 'chicken', 'dog',
#        'panda', 'dog', 'lion', 'sheep', 'pigeon', 'lion', 'mouse', 'cat',
#        'cat', 'sheep', 'cow', 'sheep', 'wolf', 'panda', 'chicken',
#        'sheep', 'rabbit', 'pigeon', 'dog', 'panda', 'rabbit', 'wolf',
#        'sheep', 'pigeon', 'mouse', 'chicken', 'cow', 'panda', 'deer',
#        'lion', 'lion', 'chicken', 'duck', 'cow', 'bear', 'chicken',
#        'chicken', 'chicken', 'chicken', 'dog', 'bear', 'duck', 'lion',
#        'monkey', 'tiger', 'mouse', 'eagle', 'panda', 'cow', 'tiger',
#        'wolf', 'tiger', 'chicken', 'duck', 'eagle', 'monkey', 'cat',
#        'chicken', 'wolf', 'monkey', 'cow', 'mouse', 'duck', 'panda',
#        'cat', 'cat', 'pigeon', 'rabbit', 'panda', 'dog', 'tiger',
#        'chicken', 'panda', 'dog', 'wolf', 'wolf', 'chicken', 'deer',
#        'bear', 'wolf', 'cat', 'human', 'deer', 'wolf', 'cat', 'tiger',
#        'lion', 'cat', 'panda', 'cat', 'mouse', 'panda', 'wolf', 'cow',
#        'cat', 'monkey', 'deer', 'elephant', 'lion', 'eagle', 'cat',
#        'duck', 'deer', 'mouse', 'sheep', 'rabbit', 'cat', 'panda', 'cat',
#        'sheep', 'dog', 'panda', 'tiger', 'dog', 'lion', 'deer', 'rabbit',
#        'chicken', 'panda', 'deer', 'cat', 'dog', 'deer', 'chicken', 'cat',
#        'elephant', 'lion', 'monkey', 'tiger', 'natural', 'cow', 'pigeon',
#        'cow', 'bear', 'tiger', 'cat', 'mouse', 'mouse', 'dog', 'sheep',
#        'dog', 'pigeon', 'dog', 'dog', 'duck', 'human', 'human', 'lion',
#        'elephant', 'panda', 'human', 'pigeon', 'lion', 'chicken', 'deer',
#        'dog', 'cat', 'human', 'panda', 'rabbit', 'human', 'deer', 'dog',
#        'cat', 'monkey', 'cat', 'human', 'pigeon', 'wolf', 'rabbit', 'cow',
#        'tiger', 'sheep', 'wolf', 'dog', 'cat', 'human', 'lion', 'rabbit',
#        'monkey', 'panda', 'wolf', 'human', 'tiger', 'pigeon', 'mouse',
#        'cat', 'duck', 'bear', 'cow', 'deer', 'wolf', 'mouse', 'wolf',
#        'panda', 'eagle', 'deer', 'mouse', 'pigeon', 'chicken', 'bear',
#        'rabbit', 'pigeon', 'rabbit', 'wolf', 'deer', 'pigeon', 'duck',
#        'tiger', 'duck', 'wolf', 'duck', 'eagle', 'tiger', 'monkey',
#        'eagle', 'tiger', 'duck', 'sheep', 'wolf'], dtype='<U8')

# %% [markdown]
# ### Model Evolution

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.600000  0.450000  0.514286   20.000000
# cat            0.705882  0.750000  0.727273   32.000000
# chicken        0.440000  0.550000  0.488889   20.000000
# cow            0.444444  0.380952  0.410256   21.000000
# deer           0.894737  0.809524  0.850000   21.000000
# dog            0.440000  0.423077  0.431373   26.000000
# duck           0.565217  0.619048  0.590909   21.000000
# eagle          0.200000  0.150000  0.171429   20.000000
# elephant       0.583333  0.350000  0.437500   20.000000
# human          0.761905  0.800000  0.780488   20.000000
# lion           0.210526  0.200000  0.205128   20.000000
# monkey         0.428571  0.450000  0.439024   20.000000
# mouse          0.294118  0.250000  0.270270   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.515152  0.708333  0.596491   24.000000
# pigeon         0.521739  0.521739  0.521739   23.000000
# rabbit         0.611111  0.550000  0.578947   20.000000
# sheep          0.750000  0.600000  0.666667   20.000000
# tiger          0.551724  0.695652  0.615385   23.000000
# wolf           0.500000  0.700000  0.583333   20.000000
# accuracy       0.531553  0.531553  0.531553    0.531553
# macro avg      0.500923  0.497916  0.493969  412.000000
# weighted avg   0.530741  0.531553  0.525611  412.000000

# %%
metrics.cohen_kappa_score(y_test,y_pred_test)
# Out:
# 0.504934097885031

# %% [markdown]
# Pipeline model

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipe = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer(orientations=8,
                                  pixels_per_cell =(10,10),cells_per_block=(3,3))),
    ('scaler',StandardScaler()),
    ('sgd',SGDClassifier(loss='hinge',learning_rate='adaptive',
                        early_stopping=True,eta0=0.1))
])

# %%
model_pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('grascale', rgb2gray_transform()),
#                 ('hogtransform',
#                  hogtransformer(orientations=8, pixels_per_cell=(10, 10))),
#                 ('scaler', StandardScaler()),
#                 ('sgd',
#                  SGDClassifier(early_stopping=True, eta0=0.1,
#                                learning_rate='adaptive'))])

# %%
y_pred_test = model_pipe.predict(x_test)

# %%
y_pred_test
# Out:
# array(['mouse', 'tiger', 'cow', 'pigeon', 'duck', 'human', 'lion',
#        'panda', 'chicken', 'elephant', 'dog', 'monkey', 'pigeon', 'mouse',
#        'tiger', 'tiger', 'human', 'duck', 'deer', 'duck', 'monkey',
#        'duck', 'tiger', 'chicken', 'lion', 'rabbit', 'dog', 'cow', 'cat',
#        'deer', 'wolf', 'eagle', 'bear', 'pigeon', 'eagle', 'mouse',
#        'human', 'tiger', 'deer', 'chicken', 'dog', 'rabbit', 'wolf',
#        'deer', 'eagle', 'eagle', 'cat', 'cat', 'chicken', 'cat', 'cat',
#        'sheep', 'tiger', 'deer', 'panda', 'sheep', 'sheep', 'tiger',
#        'elephant', 'pigeon', 'duck', 'panda', 'monkey', 'duck', 'monkey',
#        'chicken', 'tiger', 'lion', 'dog', 'chicken', 'chicken', 'cat',
#        'lion', 'bear', 'mouse', 'wolf', 'duck', 'sheep', 'panda', 'duck',
#        'dog', 'rabbit', 'sheep', 'rabbit', 'cat', 'elephant', 'mouse',
#        'monkey', 'human', 'cat', 'dog', 'tiger', 'natural', 'sheep',
#        'pigeon', 'panda', 'dog', 'cow', 'panda', 'tiger', 'sheep', 'deer',
#        'chicken', 'elephant', 'dog', 'mouse', 'duck', 'dog', 'cat',
#        'human', 'bear', 'wolf', 'chicken', 'human', 'duck', 'panda',
#        'duck', 'dog', 'lion', 'human', 'duck', 'wolf', 'wolf', 'eagle',
#        'dog', 'eagle', 'bear', 'deer', 'bear', 'tiger', 'sheep', 'eagle',
#        'chicken', 'panda', 'wolf', 'duck', 'pigeon', 'sheep', 'elephant',
#        'dog', 'pigeon', 'duck', 'cow', 'bear', 'tiger', 'panda', 'pigeon',
#        'pigeon', 'pigeon', 'bear', 'deer', 'monkey', 'pigeon', 'cat',
#        'human', 'monkey', 'duck', 'dog', 'cat', 'elephant', 'tiger',
#        'monkey', 'tiger', 'mouse', 'cat', 'chicken', 'mouse', 'monkey',
#        'dog', 'wolf', 'dog', 'sheep', 'sheep', 'deer', 'human', 'cow',
#        'cow', 'chicken', 'panda', 'panda', 'cat', 'panda', 'natural',
#        'sheep', 'panda', 'mouse', 'human', 'pigeon', 'eagle', 'deer',
#        'eagle', 'chicken', 'panda', 'monkey', 'dog', 'dog', 'pigeon',
#        'lion', 'mouse', 'cat', 'bear', 'rabbit', 'sheep', 'sheep',
#        'chicken', 'panda', 'chicken', 'sheep', 'rabbit', 'pigeon', 'dog',
#        'eagle', 'rabbit', 'bear', 'sheep', 'duck', 'monkey', 'pigeon',
#        'cow', 'panda', 'deer', 'elephant', 'dog', 'chicken', 'dog',
#        'deer', 'bear', 'tiger', 'chicken', 'sheep', 'chicken', 'cow',
#        'bear', 'tiger', 'elephant', 'elephant', 'dog', 'human', 'pigeon',
#        'panda', 'dog', 'tiger', 'wolf', 'monkey', 'sheep', 'duck',
#        'eagle', 'tiger', 'cat', 'duck', 'duck', 'monkey', 'monkey',
#        'mouse', 'elephant', 'dog', 'deer', 'cat', 'elephant', 'rabbit',
#        'panda', 'panda', 'tiger', 'dog', 'panda', 'cat', 'mouse', 'wolf',
#        'chicken', 'deer', 'lion', 'cat', 'eagle', 'human', 'deer', 'wolf',
#        'cat', 'cow', 'elephant', 'panda', 'panda', 'mouse', 'mouse',
#        'cat', 'sheep', 'deer', 'cat', 'lion', 'deer', 'elephant', 'cat',
#        'chicken', 'panda', 'natural', 'eagle', 'mouse', 'dog', 'deer',
#        'cat', 'pigeon', 'cat', 'cow', 'dog', 'pigeon', 'wolf', 'cat',
#        'lion', 'deer', 'rabbit', 'chicken', 'pigeon', 'rabbit', 'monkey',
#        'tiger', 'deer', 'duck', 'cat', 'elephant', 'sheep', 'rabbit',
#        'deer', 'duck', 'dog', 'pigeon', 'dog', 'monkey', 'deer', 'mouse',
#        'mouse', 'mouse', 'dog', 'sheep', 'panda', 'sheep', 'lion', 'dog',
#        'cow', 'human', 'human', 'tiger', 'panda', 'sheep', 'human',
#        'rabbit', 'bear', 'cat', 'deer', 'dog', 'cat', 'human', 'panda',
#        'bear', 'human', 'deer', 'panda', 'wolf', 'cow', 'wolf', 'human',
#        'chicken', 'elephant', 'eagle', 'lion', 'tiger', 'sheep', 'wolf',
#        'dog', 'cat', 'human', 'lion', 'bear', 'duck', 'panda', 'cat',
#        'duck', 'tiger', 'duck', 'rabbit', 'cat', 'duck', 'cow', 'lion',
#        'deer', 'wolf', 'elephant', 'cat', 'panda', 'wolf', 'deer', 'dog',
#        'pigeon', 'chicken', 'elephant', 'rabbit', 'elephant', 'rabbit',
#        'wolf', 'deer', 'mouse', 'elephant', 'tiger', 'duck', 'rabbit',
#        'duck', 'eagle', 'panda', 'dog', 'dog', 'tiger', 'duck', 'cow',
#        'chicken'], dtype='<U8')

# %%
cr = pd.DataFrame(sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)).T
cr
# Out:
#               precision    recall  f1-score    support
# bear           0.642857  0.450000  0.529412   20.00000
# cat            0.656250  0.656250  0.656250   32.00000
# chicken        0.666667  0.800000  0.727273   20.00000
# cow            0.357143  0.238095  0.285714   21.00000
# deer           0.666667  0.857143  0.750000   21.00000
# dog            0.457143  0.615385  0.524590   26.00000
# duck           0.535714  0.714286  0.612245   21.00000
# eagle          0.333333  0.250000  0.285714   20.00000
# elephant       0.684211  0.650000  0.666667   20.00000
# human          1.000000  0.950000  0.974359   20.00000
# lion           0.692308  0.450000  0.545455   20.00000
# monkey         0.500000  0.400000  0.444444   20.00000
# mouse          0.473684  0.450000  0.461538   20.00000
# natural        0.000000  0.000000  0.000000    1.00000
# panda          0.633333  0.791667  0.703704   24.00000
# pigeon         0.571429  0.521739  0.545455   23.00000
# rabbit         0.750000  0.600000  0.666667   20.00000
# sheep          0.416667  0.500000  0.454545   20.00000
# tiger          0.680000  0.739130  0.708333   23.00000
# wolf           0.666667  0.600000  0.631579   20.00000
# accuracy       0.594660  0.594660  0.594660    0.59466
# macro avg      0.569204  0.561685  0.558697  412.00000
# weighted avg   0.597443  0.594660  0.589140  412.00000

# %% [markdown]
# ## Grid Search
# . HyperParrameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer()),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier())
])

# %%
param_grid = [
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['optimal']  
    },
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' :['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['adaptive'],
        'sgd__eta0':[0.001,0.01]
    }
]

# %%
model_grid = GridSearchCV(estimator,
                         param_grid=param_grid,scoring='accuracy',n_jobs=1,
                          cv=3,verbose=2)

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.1s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.1s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 307, in _fit
#     **fit_params_steps[name])
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 754, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\base.py", line 702, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 17, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-980-e2d7f75fe848>", line 15, in local_hog
#     cells_per_block=self.cells_per_block)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   FitFailedWarning)
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge; total time=   0.0s
# [CV] END hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron; total time=   0.0s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 341, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
# ...
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  20.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  21.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  18.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  17.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  17.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  17.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  19.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  18.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  19.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  18.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  19.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  19.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  14.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  13.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.9s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  13.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  15.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  15.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=  15.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  15.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  15.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=  15.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  15.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  15.1s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=  15.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.3s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   8.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   7.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   7.5s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   7.0s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   7.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   7.6s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   7.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.2s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge; total time=   9.4s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.7s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge; total time=   8.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   9.8s
# [CV] END hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron; total time=   8.9s
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:925: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.70820315 0.6930052  0.71125448
#  0.73799188 0.74163265 0.74042719 0.70029893 0.68996938 0.69178644
#  0.69483777 0.69300409 0.70516068 0.72826395 0.72644024 0.72826174
#  0.69604988 0.69666259 0.69726643        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.68753296 0.69178311 0.68267343 0.74224314 0.73373619 0.7288689
#  0.69970506 0.70213039 0.69969287 0.68024588 0.67477143 0.67841885
#  0.73070037 0.71306268 0.7148875  0.70091496 0.68814788 0.69301185
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.51730308 0.46503042 0.45896654 0.4984843  0.48206095 0.46928279
#  0.58540301 0.45411697 0.50942545 0.53555126 0.51487775 0.52582998
#  0.56474391 0.20302674 0.50090631 0.50092072 0.489358   0.50272892
#  0.53190384 0.47962453 0.4899696  0.49422086 0.47901072 0.50759177
#  0.57447294 0.47233967 0.5307017  0.52461011 0.50941881 0.52766144
#  0.55379168 0.26199926 0.48206759 0.49726887 0.49179441 0.49970639
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.51306623 0.51731305 0.50457146 0.50757848 0.49786717 0.49967869
#  0.54042076 0.5161087  0.53798213 0.52158869 0.52279526 0.52702879
#  0.53919868 0.44922974 0.50516533 0.51974836 0.51003927 0.50271894
#  0.54650459 0.53130664 0.52462783 0.52521284 0.5160954  0.52704431
#  0.55683858 0.51549378 0.52947629 0.54406264 0.53251654 0.52522281
#  0.54955039 0.45227665 0.48510231 0.50395211 0.49180106 0.50212508]
#   category=UserWarning
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('grascale', rgb2gray_transform()),
#                                        ('hogtransform', hogtransformer()),
#                                        ('scale', StandardScaler()),
#                                        ('sgd', SGDClassifier())]),
#              n_jobs=1,
#              param_grid=[{'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__learning_rate': ['optimal'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']},
#                          {'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__eta0': [0.001, 0.01],
#                           'sgd__learning_rate': ['adaptive'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']}],
#              scoring='accuracy', verbose=2)

# %%
estimator.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'grascale', 'hogtransform', 'scale', 'sgd', 'hogtransform__cells_per_block', 'hogtransform__orientations', 'hogtransform__pixels_per_cell', 'scale__copy', 'scale__with_mean', 'scale__with_std', 'sgd__alpha', 'sgd__average', 'sgd__class_weight', 'sgd__early_stopping', 'sgd__epsilon', 'sgd__eta0', 'sgd__fit_intercept', 'sgd__l1_ratio', 'sgd__learning_rate', 'sgd__loss', 'sgd__max_iter', 'sgd__n_iter_no_change', 'sgd__n_jobs', 'sgd__penalty', 'sgd__power_t', 'sgd__random_state', 'sgd__shuffle', 'sgd__tol', 'sgd__validation_fraction', 'sgd__verbose', 'sgd__warm_start'])

# %%
model_grid.best_params_
# Out:
# {'hogtransform__cells_per_block': (3, 3),
#  'hogtransform__orientations': 9,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
model_grid.best_score_
# Out:
# 0.7422431405918303

# %%
model_best = model_grid.best_estimator_

# %%
y_pred = model_best.predict(x_test)

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.700000  0.700000  0.700000   20.000000
# cat            0.781250  0.781250  0.781250   32.000000
# chicken        0.750000  0.900000  0.818182   20.000000
# cow            0.785714  0.523810  0.628571   21.000000
# deer           0.875000  1.000000  0.933333   21.000000
# dog            0.681818  0.576923  0.625000   26.000000
# duck           0.818182  0.857143  0.837209   21.000000
# eagle          0.714286  0.750000  0.731707   20.000000
# elephant       0.875000  0.700000  0.777778   20.000000
# human          0.947368  0.900000  0.923077   20.000000
# lion           0.535714  0.750000  0.625000   20.000000
# monkey         0.666667  0.600000  0.631579   20.000000
# mouse          0.700000  0.700000  0.700000   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.920000  0.958333  0.938776   24.000000
# pigeon         0.739130  0.739130  0.739130   23.000000
# rabbit         0.800000  0.600000  0.685714   20.000000
# sheep          0.560000  0.700000  0.622222   20.000000
# tiger          0.740741  0.869565  0.800000   23.000000
# wolf           0.823529  0.700000  0.756757   20.000000
# accuracy       0.752427  0.752427  0.752427    0.752427
# macro avg      0.720720  0.715308  0.712764  412.000000
# weighted avg   0.758137  0.752427  0.750006  412.000000

# %%
#save the model
pickle.dump(model_best,open('dsa_model_best.pickle','wb'))

# %% [markdown]
# ## make pipeline
# {'hogtransform__cells_per_block': (3, 3),
#  'hogtransform__orientations': 9,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
from sklearn.pipeline import make_pipeline

# %%
 pipeline1 = make_pipeline(rgb2gray_transform(),
    hogtransformer(orientations=10,
                   pixels_per_cell=(8,8),
                   cells_per_block=(2,2)))

# %%
feature_vector = pipeline1.fit_transform(x_train)

# %%
#standard scaler
scalar = StandardScaler()
transformed_xtrain = scalar.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal',loss='hinge',alpha=0.01,early_stopping=True)

# %%
model.fit(transformed_xtrain,y_train)
# Out:
# SGDClassifier(alpha=0.01, early_stopping=True)

# %%
#evaluating model
feature_vector = pipeline1.fit_transform(x_test)
transformed_x = scalar.transform(feature_vector)
y_pred_test = model.predict(transformed_x)

# %%
cr = pd.DataFrame(metrics.classification_report(y_test,y_pred_test,output_dict=True)).T
cr
# Out:
#               precision    recall  f1-score    support
# bear           0.888889  0.800000  0.842105   20.00000
# cat            0.896552  0.812500  0.852459   32.00000
# chicken        0.850000  0.850000  0.850000   20.00000
# cow            0.789474  0.714286  0.750000   21.00000
# deer           0.740741  0.952381  0.833333   21.00000
# dog            0.700000  0.538462  0.608696   26.00000
# duck           0.625000  0.714286  0.666667   21.00000
# eagle          0.631579  0.600000  0.615385   20.00000
# elephant       0.842105  0.800000  0.820513   20.00000
# human          0.947368  0.900000  0.923077   20.00000
# lion           0.517241  0.750000  0.612245   20.00000
# monkey         0.789474  0.750000  0.769231   20.00000
# mouse          0.714286  0.750000  0.731707   20.00000
# natural        0.500000  1.000000  0.666667    1.00000
# panda          0.923077  1.000000  0.960000   24.00000
# pigeon         0.612903  0.826087  0.703704   23.00000
# rabbit         1.000000  0.450000  0.620690   20.00000
# sheep          0.631579  0.600000  0.615385   20.00000
# tiger          0.913043  0.913043  0.913043   23.00000
# wolf           0.842105  0.800000  0.820513   20.00000
# accuracy       0.766990  0.766990  0.766990    0.76699
# macro avg      0.767771  0.776052  0.758771  412.00000
# weighted avg   0.783962  0.766990  0.766174  412.00000

# %%
#save models for flask app
pickle.dump(model,open('dsa_image_classification_sgd.pickle','wb'))

# %%
pickle.dump(scalar,open('dsa_scaler.pickle','wb'))
